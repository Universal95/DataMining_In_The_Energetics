# %% [markdown]
# # Adat bővítés

# %%
import pandas as pd
import math
import matplotlib.pyplot as plt
import matplotlib
from matplotlib.dates import YearLocator, MonthLocator, DateFormatter
from datetime import datetime 
import numpy as np

# %%
data = pd.read_csv('database_2017_03.csv')
wheater = pd.read_csv('weather_info.csv')
database = pd.merge(data, wheater, on='date')
database['date'] = pd.to_datetime(database['date'])
database['day_of_week'] = np.nan
print(len(database))
for i in range(0, len(database)):
    database.set_value(i, 'day_of_week', database.loc[i]['date'].weekday())
    database.set_value(i, 'tick', database.loc[i]['tick'].split('-')[0])
#     if ((i % 1000) == 0):
#         print(i)
# database
# Out:
# 10944
# 0
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000

# %%
database = database.dropna()
database['holiday'] = 0
database['workday'] = 0

database.loc[(database['day_of_week'] == 1), 'workday'] = 1
database.loc[(database['day_of_week'] == 2), 'workday'] = 1
database.loc[(database['day_of_week'] == 3), 'workday'] = 1
database.loc[(database['day_of_week'] == 4), 'workday'] = 1
database.loc[(database['day_of_week'] == 5), 'workday'] = 1

database.loc[(database['date'] == '2016-01-01'), 'holiday'] = 1
database.loc[(database['date'] == '2016-03-15'), 'holiday'] = 1
database.loc[(database['date'] == '2016-03-27'), 'holiday'] = 1
database.loc[(database['date'] == '2016-03-28'), 'holiday'] = 1
database.loc[(database['date'] == '2016-05-01'), 'holiday'] = 1
database.loc[(database['date'] == '2016-05-15'), 'holiday'] = 1
database.loc[(database['date'] == '2016-08-20'), 'holiday'] = 1
database.loc[(database['date'] == '2016-10-23'), 'holiday'] = 1
database.loc[(database['date'] == '2016-11-01'), 'holiday'] = 1
database.loc[(database['date'] == '2016-12-25'), 'holiday'] = 1
database.loc[(database['date'] == '2016-12-26'), 'holiday'] = 1
database.loc[(database['date'] == '2016-01-01') | \
             (database['date'] == '2016-03-15') | \
             (database['date'] == '2016-03-27') | \
             (database['date'] == '2016-03-28') | \
             (database['date'] == '2016-05-01') | \
             (database['date'] == '2016-05-15') | \
             (database['date'] == '2016-08-20') | \
             (database['date'] == '2016-10-23') | \
             (database['date'] == '2016-11-01') | \
             (database['date'] == '2016-12-25') | \
             (database['date'] == '2016-12-26'), 'workday'] = 0

database.loc[(database['date'] == '2017-01-01'), 'holiday'] = 1
database.loc[(database['date'] == '2017-03-15'), 'holiday'] = 1
database.loc[(database['date'] == '2017-04-16'), 'holiday'] = 1
database.loc[(database['date'] == '2017-04-17'), 'holiday'] = 1
database.loc[(database['date'] == '2017-05-01'), 'holiday'] = 1
database.loc[(database['date'] == '2017-06-04'), 'holiday'] = 1
database.loc[(database['date'] == '2017-08-20'), 'holiday'] = 1
database.loc[(database['date'] == '2017-10-23'), 'holiday'] = 1
database.loc[(database['date'] == '2017-11-01'), 'holiday'] = 1
database.loc[(database['date'] == '2017-12-25'), 'holiday'] = 1
database.loc[(database['date'] == '2017-12-26'), 'holiday'] = 1
database.loc[(database['date'] == '2017-01-01') | \
             (database['date'] == '2017-03-15') | \
             (database['date'] == '2017-04-16') | \
             (database['date'] == '2017-04-17') | \
             (database['date'] == '2017-05-01') | \
             (database['date'] == '2017-06-04') | \
             (database['date'] == '2017-08-20') | \
             (database['date'] == '2017-10-23') | \
             (database['date'] == '2017-11-01') | \
             (database['date'] == '2017-12-25') | \
             (database['date'] == '2017-12-26'), 'workday'] = 0

database.to_csv('Data_Expansion.csv', sep=',', index=False)
database
# Out:
#             date tick  export  import  system_load  max  min  rain  snow  \
# 10927       13        4          4.0        0        1
# 10928       13        4          4.0        0        1
# 10929       13        4          4.0        0        1
# 10930       13        4          4.0        0        1
# 10931       13        4          4.0        0        1
# 10932       13        4          4.0        0        1
# 10933       13        4          4.0        0        1
# 10934       13        4          4.0        0        1
# 10935       13        4          4.0        0        1
# 10936       13        4          4.0        0        1
# 10937       13        4          4.0        0        1
# 10938       13        4          4.0        0        1
# 10939       13        4          4.0        0        1
# 10940       13        4          4.0        0        1
# 10941       13        4          4.0        0        1
# 10942       13        4          4.0        0        1
# 10943       13        4          4.0        0        1
#
# [10942 rows x 14 columns]

# %% [markdown]
# # Homersekletenkent az atlagos rendszerterheles es szoras kiszamolasa

# %%
database.__delitem__('date')
database.__delitem__('tick')
database.__delitem__('min')
database.__delitem__('rain')
database.__delitem__('snow')
database.__delitem__('avg_max')
database.__delitem__('avg_min')
database.__delitem__('day_of_week')
database.__delitem__('holiday')
database.__delitem__('workday')

# %%
values = pd.DataFrame()
value = []          
for i in range(database['max'].min(), database['max'].max()):
    
    value = [database[database['max']==i].sum()/database[database['max']==i].count(), \
             np.var(database[database['max']==i], 0)]
    print(value)
    values = values.append(value, ignore_index=True)

values = values.dropna()
cols = values.columns.tolist()
cols = cols[-2:] + cols[:-2]
values = values[cols]
values = values.rename(index=str, columns={'max': '˚C', 'system_load':'avg_sysload', \
                                           'export': 'avg_export', 'import': 'avg_import'})

values
# Out:
# [export         1219.958333
# import         2259.458333
# system_load    5175.000000
# max              -9.000000
# dtype: float64, export         122412.789931
# import          32863.581597
# system_load    235228.250000
# max                 0.000000
# dtype: float64]
# [export        NaN
# import        NaN
# system_load   NaN
# max           NaN
# dtype: float64, export        NaN
# import        NaN
# system_load   NaN
# max           NaN
# dtype: float64]
# [export         1379.166667
# import         2709.104167
# system_load    5179.833333
# max              -7.000000
# dtype: float64, export          68745.888889
# import         212016.218316
# system_load    443600.680556
# max                 0.000000
# dtype: float64]
# [export         1105.597222
# import         2985.722222
# system_load    5670.055556
# max              -6.000000
# dtype: float64, export         170228.157215
# import          49074.895062
# system_load    442194.246914
# max                 0.000000
# dtype: float64]
# [export         1347.525000
# import         2464.341667
# system_load    4767.166667
# max              -5.000000
# dtype: float64, export         162909.132708
# import         169764.274931
# system_load    543320.972222
# max                 0.000000
# dtype: float64]
# [export         1060.277778
# import         2448.680556
# system_load    4967.277778
# max              -4.000000
# dtype: float64, export         293015.783951
# import          31595.161844
# system_load    593284.117284
# max                 0.000000
# dtype: float64]
# [export          883.583333
# import         2535.277778
# system_load    5017.576389
# max              -3.000000
# dtype: float64, export         323522.937500
# import          94387.047840
# system_load    699261.063609
# max                 0.000000
# dtype: float64]
# [export          668.398810
# import         2586.886905
# system_load    5249.803571
# max              -2.000000
# dtype: float64, export         247573.465951
# import          53397.862209
# system_load    472077.991178
# max                 0.000000
# dtype: float64]
# [export          903.849359
# import         2529.567308
# system_load    5234.842949
# max              -1.000000
# dtype: float64, export         219277.102307
# import         113680.501880
# system_load    535700.267002
# max                 0.000000
# dtype: float64]
# [export          795.583333
# import         2322.916667
# system_load    5239.145833
# max               0.000000
# dtype: float64, export         269690.243056
# import          90249.895833
# system_load    445314.124566
# max                 0.000000
# dtype: float64]
# [export          848.220833
# import         2435.325000
# system_load    5394.433333
# max               1.000000
# dtype: float64, export         235450.280399
# import          84775.744375
# system_load    396553.662222
# max                 0.000000
# dtype: float64]
# [export          788.658333
# import         2465.350000
# system_load    5312.529167
# max               2.000000
# dtype: float64, export         216878.349931
# import         121315.594167
# system_load    520359.990816
# max                 0.000000
# dtype: float64]
# [export          892.932692
# import         2463.775641
# system_load    5097.974359
# max               3.000000
# dtype: float64, export         267800.710213
# import         112390.571458
# system_load    497452.948060
# max                 0.000000
# dtype: float64]
# [export          668.587500
# import         2191.579167
# system_load    4965.670833
# max               4.000000
# dtype: float64, export         238210.367344
# import         142768.810399
# system_load    494336.512483
# max                 0.000000
# dtype: float64]
# [export          523.416667
# import         2211.053571
# system_load    4861.101190
# max               5.000000
# dtype: float64, export         126680.743056
# import         228259.003082
# system_load    390218.876665
# max                 0.000000
# dtype: float64]
# [export          648.500000
# import         2436.491667
# system_load    4873.016667
# max               6.000000
# dtype: float64, export         268324.908333
# import         183796.024931
# system_load    535739.133056
# max                 0.000000
# dtype: float64]
# [export          632.375000
# import         2167.799242
# system_load    5063.371212
# max               7.000000
# dtype: float64, export         121027.249527
# import          87947.205909
# system_load    384769.695535
# max                 0.000000
# dtype: float64]
# [export          472.032051
# import         2234.346154
# system_load    4977.282051
# max               8.000000
# dtype: float64, export          98614.274614
# import         137283.373767
# system_load    441501.337114
# max                 0.000000
# dtype: float64]
# [export          693.481771
# import         2156.674479
# system_load    4858.674479
# max               9.000000
# dtype: float64, export         153538.515293
# import         126417.922682
# system_load    431191.381015
# max                 0.000000
# dtype: float64]
# [export          546.289683
# import         2121.015873
# system_load    4825.847222
# max              10.000000
# dtype: float64, export         117876.229576
# import         161686.325145
# system_load    468419.490548
# max                 0.000000
# dtype: float64]
# [export          560.628968
# import         2087.769841
# system_load    4765.363095
# max              11.000000
# dtype: float64, export         190288.542891
# import         128374.244646
# system_load    413567.005067
# max                 0.000000
# dtype: float64]
# [export          674.749583
# import         2085.460768
# system_load    4597.884808
# max              12.000000
# dtype: float64, export         179152.100897
# import         173354.729262
# system_load    446751.013442
# max                 0.000000
# dtype: float64]
# [export          732.433400
# import         2142.425447
# system_load    4622.506958
# max              13.000000
# dtype: float64, export         146493.772403
# import         194039.166907
# system_load    427976.874206
# max                 0.000000
# dtype: float64]
# [export          653.163690
# import         2201.619048
# system_load    4705.422619
# max              14.000000
# dtype: float64, export         162914.946420
# import         135532.604875
# system_load    422435.035679
# max                 0.000000
# dtype: float64]
# [export          623.744444
# import         2149.272222
# system_load    4672.330556
# max              15.000000
# dtype: float64, export         134460.901358
# import         241654.459228
# system_load    372774.554622
# max                 0.000000
# dtype: float64]
# [export          605.583333
# import         2025.136905
# system_load    4481.125000
# max              16.000000
# dtype: float64, export         136294.493056
# import         163047.820543
# system_load    462134.859375
# max                 0.000000
# dtype: float64]
# [export          623.583333
# import         2078.525000
# system_load    4609.458333
# max              17.000000
# dtype: float64, export         219656.909722
# import         146229.766042
# system_load    405815.981597
# max                 0.000000
# dtype: float64]
# [export          618.178571
# import         1869.565476
# system_load    4495.148810
# max              18.000000
# dtype: float64, export         156709.980017
# import         237804.555237
# system_load    419934.424284
# max                 0.000000
# dtype: float64]
# [export          524.833333
# import         1891.201923
# system_load    4419.342949
# max              19.000000
# dtype: float64, export         115265.074786
# import         183529.276535
# system_load    307780.936873
# max                 0.000000
# dtype: float64]
# [export          656.116667
# import         2118.737500
# system_load    4562.416667
# max              20.000000
# dtype: float64, export         115883.753056
# import         214751.201927
# system_load    333351.801389
# max                 0.000000
# dtype: float64]
# [export          614.208333
# import         1886.009259
# system_load    4356.370370
# max              21.000000
# dtype: float64, export         170635.590856
# import         178060.351766
# system_load    381918.149863
# max                 0.000000
# dtype: float64]
# [export          503.050000
# import         1980.335417
# system_load    4570.600000
# max              22.000000
# dtype: float64, export         124491.426667
# import         199151.772912
# system_load    276607.027500
# max                 0.000000
# dtype: float64]
# [export          609.076923
# import         1931.073718
# system_load    4466.358974
# max              23.000000
# dtype: float64, export         127090.045365
# import         158399.125976
# system_load    314056.800625
# max                 0.000000
# dtype: float64]
# [export          527.047619
# import         1965.738095
# system_load    4394.880952
# max              24.000000
# dtype: float64, export         139204.450113
# import         147763.348073
# system_load    235905.009637
# max                 0.000000
# dtype: float64]
# [export          462.397059
# import         1960.426471
# system_load    4405.000000
# max              25.000000
# dtype: float64, export         101925.734501
# import         158912.774005
# system_load    321317.539216
# max                 0.000000
# dtype: float64]
# [export          488.770833
# import         2038.440476
# system_load    4522.958333
# max              26.000000
# dtype: float64, export         103202.254030
# import         170906.020266
# system_load    354883.819692
# max                 0.000000
# dtype: float64]
# [export          389.563596
# import         1869.642544
# system_load    4474.122807
# max              27.000000
# dtype: float64, export          61063.447710
# import         195169.045471
# system_load    405894.410357
# max                 0.000000
# dtype: float64]
# [export          551.727273
# import         1911.799242
# system_load    4472.227273
# max              28.000000
# dtype: float64, export         114310.986226
# import         113444.274090
# system_load    388557.357438
# max                 0.000000
# dtype: float64]
# [export          640.544444
# import         1945.791667
# system_load    4457.544444
# max              29.000000
# dtype: float64, export         117158.986914
# import         158739.614931
# system_load    387410.714691
# max                 0.000000
# dtype: float64]
# [export          809.708333
# import         1862.750000
# system_load    4417.100000
# max              30.000000
# dtype: float64, export         142633.331597
# import         100548.145833
# system_load    395196.548333
# max                 0.000000
# dtype: float64]
# [export          596.083333
# import         1995.656250
# system_load    4655.161458
# max              31.000000
# dtype: float64, export          76038.118056
# import         156611.767253
# system_load    471549.031223
# max                 0.000000
# dtype: float64]
# [export          605.513889
# import         1993.388889
# system_load    4474.625000
# max              32.000000
# dtype: float64, export         191077.944252
# import         205863.237654
# system_load    440837.651042
# max                 0.000000
# dtype: float64]
# [export          815.625000
# import         2065.791667
# system_load    4832.583333
# max              33.000000
# dtype: float64, export         109042.734375
# import         204048.581597
# system_load    653193.326389
# max                 0.000000
# dtype: float64]
# [export          450.694444
# import         2154.513889
# system_load    4968.208333
# max              34.000000
# dtype: float64, export          95812.156636
# import         184269.944252
# system_load    414805.831597
# max                 0.000000
# dtype: float64]
#       avg_sysload    ˚C     avg_export     avg_import
