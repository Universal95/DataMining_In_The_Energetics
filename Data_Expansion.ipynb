# %% [markdown]
# # Adat bővítés

# %%
import pandas as pd
import math
import matplotlib.pyplot as plt
import matplotlib
from matplotlib.dates import YearLocator, MonthLocator, DateFormatter
from datetime import datetime 
import numpy as np

# %%
data = pd.read_csv('database_2017_03.csv')
wheater = pd.read_csv('weather_info.csv')
database = pd.merge(data, wheater, on='date')
database['date'] = pd.to_datetime(database['date'])
database['day_of_week'] = np.nan
print(len(database))
for i in range(0, len(database)):
    database.__getitem__('day_of_week').__setitem__(i, database.__getitem__('date').__getitem__(i).weekday())
#     database['day_of_week'][i].__setitem__(database['date'][i].weekday())
#     database.__getitem__('day_of_week').__setitem__('', value)
    if ((i % 1000) == 0):
        print(i)
database
# Out:
# 10944
# nan
# 0
# /Users/krisz/anaconda3/lib/python3.6/site-packages/ipykernel/__main__.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
#             date   tick  export  import  system_load  max  min  rain  snow  \
# 0     2016-01-01    0-1  1503.0  2351.0       4071.0   -3  -10     0   0.0
# 1     2016-01-01    1-2  1613.0  2282.0       3873.0   -3  -10     0   0.0
# 2     2016-01-01    2-3  1779.0  2224.0       3581.0   -3  -10     0   0.0
# 3     2016-01-01    3-4  1923.0  2160.0       3356.0   -3  -10     0   0.0
# 4     2016-01-01    4-5  1922.0  2115.0       3294.0   -3  -10     0   0.0
# 5     2016-01-01    5-6  1843.0  2037.0       3302.0   -3  -10     0   0.0
# 6     2016-01-01    6-7  1847.0  2067.0       3375.0   -3  -10     0   0.0
# 7     2016-01-01    7-8  1835.0  2126.0       3436.0   -3  -10     0   0.0
# 8     2016-01-01    8-9  1735.0  2165.0       3565.0   -3  -10     0   0.0
# 9     2016-01-01   9-10  1516.0  2098.0       3755.0   -3  -10     0   0.0
# 10    2016-01-01  10-11  1380.0  2115.0       3916.0   -3  -10     0   0.0
# 11    2016-01-01  11-12  1244.0  2101.0       4058.0   -3  -10     0   0.0
# 12    2016-01-01  12-13  1135.0  2033.0       4132.0   -3  -10     0   0.0
# 13    2016-01-01  13-14  1074.0  1924.0       4075.0   -3  -10     0   0.0
# 14    2016-01-01  14-15  1170.0  2060.0       4073.0   -3  -10     0   0.0
# 15    2016-01-01  15-16  1254.0  2202.0       4129.0   -3  -10     0   0.0
# 16    2016-01-01  16-17   936.0  2212.0       4404.0   -3  -10     0   0.0
# 17    2016-01-01  17-18   993.0  2295.0       4523.0   -3  -10     0   0.0
# 18    2016-01-01  18-19  1101.0  2365.0       4497.0   -3  -10     0   0.0
# 19    2016-01-01  19-20  1137.0  2360.0       4468.0   -3  -10     0   0.0
# 20    2016-01-01  20-21  1258.0  2388.0       4372.0   -3  -10     0   0.0
# 21    2016-01-01  21-22  1347.0  2417.0       4267.0   -3  -10     0   0.0
# 22    2016-01-01  22-23  1571.0  2450.0       4089.0   -3  -10     0   0.0
# 23    2016-01-01  23-24  1646.0  2333.0       3879.0   -3  -10     0   0.0
# 24    2016-01-02    0-1  1708.0  2195.0       3612.0   -5   -8     0   0.5
# 25    2016-01-02    1-2  1842.0  2183.0       3475.0   -5   -8     0   0.5
# 3            2       -2          4.0
# 4            2       -2          4.0
# 5            2       -2          4.0
# 6            2       -2          4.0
# 7            2       -2          4.0
# 8            2       -2          4.0
# 9            2       -2          4.0
# 10           2       -2          4.0
# 11           2       -2          4.0
# 12           2       -2          4.0
# 13           2       -2          4.0
# 14           2       -2          4.0
# 15           2       -2          4.0
# 16           2       -2          4.0
# 17           2       -2          4.0
# 18           2       -2          4.0
# 19           2       -2          4.0
# 20           2       -2          4.0
# 21           2       -2          4.0
# 22           2       -2          4.0
# 23           2       -2          4.0
# 24           2       -2          5.0
# 25           2       -2          5.0
# 26           2       -2          5.0
# 27           2       -2          5.0
# 28           2       -2          5.0
# 29           2       -2          5.0
# ...        ...      ...          ...
# 10914       13        4          3.0
# 10915       13        4          3.0
# 10916       13        4          3.0
# 10917       13        4          3.0
# 10918       13        4          3.0
# 10919       13        4          3.0
# 10920       13        4          4.0
# 10921       13        4          4.0
# 10922       13        4          4.0
# 10923       13        4          4.0
# 10924       13        4          4.0
# 10925       13        4          4.0
# 10926       13        4          4.0
# 10927       13        4          4.0
# 10928       13        4          4.0
# 10929       13        4          4.0
# 10930       13        4          4.0
# 10931       13        4          4.0
# 10932       13        4          4.0
# 10933       13        4          4.0
# 10934       13        4          4.0
# 10935       13        4          4.0
# 10936       13        4          4.0
# 10937       13        4          4.0
# 10938       13        4          4.0
# 10939       13        4          4.0
# 10940       13        4          4.0
# 10941       13        4          4.0
# 10942       13        4          4.0
# 10943       13        4          4.0
#
# [10944 rows x 12 columns]

# %%
database['holiday'] = 0
database.loc[(database['date'] == '2016-01-01'), 'holiday'] = 1
database.loc[(database['date'] == '2016-03-15'), 'holiday'] = 1
database.loc[(database['date'] == '2016-03-27'), 'holiday'] = 1
database.loc[(database['date'] == '2016-03-28'), 'holiday'] = 1
database.loc[(database['date'] == '2016-05-01'), 'holiday'] = 1
database.loc[(database['date'] == '2016-03-28'), 'holiday'] = 1
database.loc[(database['date'] == '2016-08-20'), 'holiday'] = 1
database.loc[(database['date'] == '2016-10-23'), 'holiday'] = 1
database.loc[(database['date'] == '2016-11-01'), 'holiday'] = 1
database.loc[(database['date'] == '2016-12-25'), 'holiday'] = 1
database.loc[(database['date'] == '2016-12-26'), 'holiday'] = 1

database.loc[(database['date'] == '2017-01-01'), 'holiday'] = 1
database.loc[(database['date'] == '2017-03-15'), 'holiday'] = 1
database.loc[(database['date'] == '2017-04-16'), 'holiday'] = 1
database.loc[(database['date'] == '2017-04-17'), 'holiday'] = 1
database.loc[(database['date'] == '2017-05-01'), 'holiday'] = 1
database.loc[(database['date'] == '2017-06-04'), 'holiday'] = 1
database.loc[(database['date'] == '2017-08-20'), 'holiday'] = 1
database.loc[(database['date'] == '2017-10-23'), 'holiday'] = 1
database.loc[(database['date'] == '2017-11-01'), 'holiday'] = 1
database.loc[(database['date'] == '2017-12-25'), 'holiday'] = 1
database.loc[(database['date'] == '2017-12-26'), 'holiday'] = 1
# database.loc[database['date'] == '2016-01-01']['holiday']

database.to_csv('Data_Expansion.csv', sep=',', index=False)
