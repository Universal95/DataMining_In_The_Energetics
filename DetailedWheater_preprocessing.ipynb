# %%
import pandas as pd
import numpy as np

# %%
weather = pd.read_csv('idojaras_reszletes.csv')

# %%
new_weather = pd.DataFrame();

for i in range(0, 10):
    new_weather = new_weather.append(weather[weather['time'] == '0'+ str(i) + ':00'])
for i in range(10, 24):
    new_weather = new_weather.append(weather[weather['time'] == str(i) + ':00'])
new_weather = new_weather.sort(['date', 'time'])
    
new_weather['time'] = pd.to_numeric((new_weather['time'].str.split(':').str.get(0)))
new_weather = new_weather.rename(index=str, columns={'time':'tick'})    
    
new_weather
# Out:
# /Users/krisz/anaconda3/lib/python3.6/site-packages/ipykernel/__main__.py:7: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#              date  tick  temperature  windspeed  winddirection  humidity
# 0      2016-01-01     0        -8.77       1.68         143.79     86.41
# 4      2016-01-01     1        -9.02       2.40          99.74     86.23
# 8      2016-01-01     2        -9.27       2.04         115.74     87.92
# 12     2016-01-01     3        -9.36       1.57         141.67     87.24
# 16     2016-01-01     4        -9.46       1.52         129.25     88.61
# 20     2016-01-01     5       -10.10       1.65         147.49     87.90
# 24     2016-01-01     6       -10.06       1.64         114.33     90.94
# 28     2016-01-01     7        -9.94       1.59         106.60     90.47
# 32     2016-01-01     8        -7.51       1.27         148.19     87.18
# 36     2016-01-01     9        -5.52       1.38         182.93     84.81
# ...

# %%
data = pd.read_csv('Data_Expansion.csv')
new_data = pd.merge(data, new_weather, on=['date', 'tick'])

new_data.__delitem__('max')
new_data.__delitem__('min')
new_data.__delitem__('rain')
new_data.__delitem__('snow')
new_data.__delitem__('avg_max')
new_data.__delitem__('avg_min') 
# new_data.__delitem__('time')

new_data
# Out:
#              date  tick  export  import  system_load  day_of_week  holiday  \
# 0      2016-01-01     0  1503.0  2351.0       4071.0          4.0        1
# 1      2016-01-01     1  1613.0  2282.0       3873.0          4.0        1
# 2      2016-01-01     2  1779.0  2224.0       3581.0          4.0        1
# 3      2016-01-01     3  1923.0  2160.0       3356.0          4.0        1
# 4      2016-01-01     4  1922.0  2115.0       3294.0          4.0        1
# 5      2016-01-01     5  1843.0  2037.0       3302.0          4.0        1
# 6      2016-01-01     6  1847.0  2067.0       3375.0          4.0        1
# 7      2016-01-01     7  1835.0  2126.0       3436.0          4.0        1
# 8      2016-01-01     8  1735.0  2165.0       3565.0          4.0        1
# 9      2016-01-01     9  1516.0  2098.0       3755.0          4.0        1
# 10     2016-01-01    10  1380.0  2115.0       3916.0          4.0        1
# ...

# %%
new_data.to_csv('processed_detailedweather.csv', sep=',', index=False)
